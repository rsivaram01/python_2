# %%
# %sql
Explain your project arch

# %%
Data Eng:-
=========

Metlife  ===> us based insurance company  ===> policys 

EMP
members 
email
policy_related_data


===========================> raw_data_zone, curated_data_zone, reporting_layer 
rdz, cdz, ddz


=====================================================================================================================
we are part of MDH ===> Metlife Data Hub

project arch

Two env
1. Onpremise
2. Azure Cloud

Onpremise  ===> Hadoop ecosystem ===> HDFS, Spark, Hive 

Mainframes ======> DB2====> MFT Server/Informatica ======>  HDFS(json, csv, fixedwidth)  =====> Spark (pyspark) ========> Hive(ORC) 


Azure Cloud ====> ADLS, ADF(Azure Data Factory) and Databricks 

ADLS ==> used as a datalake 
DATA FACTORY ====> ETL Service
Databricks =====> For data processing

DB2, Sql Server, postgress db =======> ADF =======> ADLS ======> Databricks (unity catlouge)


==============================================================================================================================


As a Data Eng, what is your data to day responsbilities

rdz, cdz and ddz 


creat a table in ddz ===> table_name, fields(name, datatype, where we can take the fields), mapping document 

# emp_name cdz.emp name 

Business owner ===> BA ====> mapping_doc ===> Data eng ===> build the table ===> dev ====> unit testing
