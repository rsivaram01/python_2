# %%
# methods in strings:-
=====================
title()
upper()
lower()
islower()
isupper()
swapcase()
isdigit()
isalpha()

# %%
lang = 'python'

# %%
lang
# Out:
# 'python'

# %%
#req :- Python 

print(lang.title())
# Out:
# Python

# %%
lang.title()
# Out:
# 'Python'

# %%
lang1 = lang.title()

# %%
lang1
# Out:
# 'Python'

# %%
# req:- I want to get all letters in upper case

# upper()

lang.upper()
# Out:
# 'PYTHON'

# %%
city = 'HYDB'

# %%
city
# Out:
# 'HYDB'

# %%
# req:- I want to get all letters in lower case

# lower()

city.lower()
# Out:
# 'hydb'

# %%
# I want to know wheather my all letters are lower case or not

# islower()

# %%
lang
# Out:
# 'python'

# %%
lang.islower()
# Out:
# True

# %%
city.islower()
# Out:
# False

# %%
'AfdfdjD'.islower()
# Out:
# False

# %%
# I want to know wheather my all letters are upper case or not

# isupper()

# %%
city.isupper()
# Out:
# True

# %%
city
# Out:
# 'HYDB'

# %%
lang
# Out:
# 'python'

# %%
lang.isupper()
# Out:
# False

# %%
# it return boolean value

True
False

# %%
sentance = 'This is my sessIon'

# %%
sentance
# Out:
# 'This is my sessIon'

# %%
# req:- 

input :- This is my sessIon
output :- tHIS IS MY SESSiON

# %%
sentance
# Out:
# 'This is my sessIon'

# %%
# swapcase()

sentance.swapcase()
# Out:
# 'tHIS IS MY SESSiON'

# %%
# isdigit()

num = 12
num1 = '12'

# %%
num1.isdigit()
# Out:
# True

# %%
num.isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 num.isdigit()
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
type(num)
# Out:
# int

# %%
type(num1)
# Out:
# str

# %%
lang
# Out:
# 'python'

# %%
lang.isdigit()
# Out:
# False

# %%
ss = 'assa123ffd'

# %%
ss.isdigit()
# Out:
# False

# %%
# isalnum()

# %%
ss.isalnum()
# Out:
# True

# %%
lang.isalnum()
# Out:
# True

# %%
tt = 'dssa12*$#$'

# %%
tt.isalnum()
# Out:
# False

# %%
# isalpha()

# %%
tt.isalpha()
# Out:
# False

# %%
lang.isalpha()
# Out:
# True

# %%
# f - strings:-
=============

formatted strings

# %%
marks = 20

# %%
# req:- I should print the below statament

I got 20 marks

# %%
print(f"I got {marks} marks")
# Out:
# I got 20 marks

# %%
#req:- my fav lag is python

# %%
print(f"my fav lang is {lang}")
# Out:
# my fav lang is python

# %%
sent1 = f"my fav lang is {lang}"

# %%
sent1
# Out:
# 'my fav lang is python'

# %%
n = 0.9

# %%
type(n)
# Out:
# float

# %%
# efficent way of declaring var in python

# %%
# a = 10
# b = 30
# c = 90

# %%
x,y,z = 10,20,30

# %%
print(x,y,z)
# Out:
# 10 20 30

# %%
s = 'aa'
s1 = 22
s3 = 0.9

# %%
type(s)
# Out:
# str

# %%
type(s1)
# Out:
# int

# %%
type(s3)
# Out:
# float

# %%
char ===> d
string ==> afdhdshds
int ===> 12, 76 
float ==> 76.0 
double ==> 

boolean ==> True / False
