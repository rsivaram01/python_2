# %%
# strip:- strip is used to remove white spaces
--------

lstrip ---> space left 
rstrip ---> right
strip  --->

# %%
name = 'aaa   '

# %%
print(name)
# Out:
# aaa

# %%
name
# Out:
# 'aaa   '

# %%
name1 = 'aaa'

# %%
name1
# Out:
# 'aaa'

# %%
print(name,name1)
# Out:
# aaa    aaa

# %%
name == name1
# Out:
# False

# %%
name
# Out:
# 'aaa   '

# %%
name.rstrip()
# Out:
# 'aaa'

# %%
aa = '   aaaa'

# %%
aa
# Out:
# '   aaaa'

# %%
aa.lstrip()
# Out:
# 'aaaa'

# %%
aa.strip()
# Out:
# 'aaaa'

# %%
# Tab Delimeters in python:-
---------------------------

\n  ====> which used to jump the control from one line to another line
\t =====> which is used to one tab space

# %%
print("this is my notebook")
# Out:
# this is my notebook

# %%
print("this is my\n notebook")
# Out:
# this is my
#  notebook

# %%
print("this is my\n note\nbook")
# Out:
# this is my
#  note
# book

# %%
# \t =====> which is used to one tab space


print("python")
# Out:
# python

# %%
print("py\tthon")
# Out:
# py	thon

# %%
my fav lang are:
    1. python
    2. java
    3. scala

# %%
print("my fav lang are:\n\t1. python\n\t2. java\n\t3. scala")
# Out:
# my fav lang are:
# 	1. python
# 	2. java
# 	3. scala

# %%
# mul
4 * 3
# Out:
# 12

# %%
# 2 power 3
2 ** 3
# Out:
# 8

# %%
# List :-
=========

List is one of the data stracture in python
list is collection of multiple items

Properties:-
==========
List is a mutable datatype

How to declare a list?
----------------------

list can be defined using []

example:-
---------
L1 = [1,2,3]


=====================================================================================================================================

Array vs List:-
-------------

Array used to store same types
List can be used to store mutiple types

array1 = 1,2,3,4
array2 = 'aaa','bb','hhh'


L1 = [1,'aaa',3.0,'a',True]

# %%
stu = ['ashok','naveen','murali']

# %%
stu
# Out:
# ['ashok', 'naveen', 'murali']

# %%
type(stu)
# Out:
# list

# %%
# how to access data inside a list

WE can access data of a list by using index position

# %%
# +index ==> it always starts with 0  --> moves from left to right
        0     ,   1    ,   2
stu = ['ashok','naveen','murali']
            -3 , -2    ,  -1

# -index ==> it always starts with -1  --> moves from right to left

# %%
print(stu)
# Out:
# ['ashok', 'naveen', 'murali']

# %%
stu[0].upper()
# Out:
# 'ASHOK'

# %%
print(stu[2])
# Out:
# murali

# %%
# req:- I want to print below

my stu name is Murali.

# %%
print(f"my stu name is {stu[2].title()}")
# Out:
# my stu name is Murali

# %%
print(f"my stu name is {stu[-1].title()}")
# Out:
# my stu name is Murali

# %%
# req:- I want to replace an item with another item

# %%
stu
# Out:
# ['ashok', 'naveen', 'murali']

# %%
stu[1] = 'NAVEEN'

# %%
stu
# Out:
# ['ashok', 'NAVEEN', 'murali']

# %%
stu[2] = 'aa'

# %%
stu
# Out:
# ['ashok', 'NAVEEN', 'aa']

# %%
# how to delete an item from list

# pop()

# %%
stu.pop()
# Out:
# 'aa'

# %%
stu
# Out:
# ['ashok', 'NAVEEN']

# %%
stu.pop()
# Out:
# 'NAVEEN'

# %%
stu
# Out:
# ['ashok']

# %%
# how to add new item to existing list

# append()

# %%
stu
# Out:
# ['ashok']

# %%
stu.append('aasad')

# %%
stu
# Out:
# ['ashok', 'aasad']

# %%
stu.append("tryeuij")

# %%
stu
# Out:
# ['ashok', 'aasad', 'tryeuij']

# %%
stu.append("oops")

# %%
stu
# Out:
# ['ashok', 'aasad', 'tryeuij', 'oops']

# %%
stu.pop()
# Out:
# 'oops'

# %%
stu
# Out:
# ['ashok', 'aasad', 'tryeuij']

# %%
# how to delete a perticualr item in a list

stu.pop(1)
# Out:
# 'aasad'

# %%
stu
# Out:
# ['ashok', 'tryeuij']

# %%
# req:-  index()

# index method is used to find index position of an item in a list

# %%
stu.index('ashok')
# Out:
# 0

# %%
stu.index('tryeuij')
# Out:
# 1
