# %%
num = [20,1,3,6,3]

# %%
num
# Out:
# [20, 1, 3, 6, 3]

# %%
# organising list

sort()
sorted()

# %%
num
# Out:
# [20, 1, 3, 6, 3]

# %%
num.sort()

# %%
num
# Out:
# [1, 3, 3, 6, 20]

# %%
alpha = ['b','a','r','g','n']

# %%
sorted(alpha)
# Out:
# ['a', 'b', 'g', 'n', 'r']

# %%
alpha
# Out:
# ['b', 'a', 'r', 'g', 'n']

# %%
Sort:-  sort method will sorts the data inside a list
sorted :- it wil return a sorted list

# %%
# how to reverse a list

# reverse()

# %%
alpha
# Out:
# ['b', 'a', 'r', 'g', 'n']

# %%
# n,g,r,a,b

alpha.reverse()

# %%
alpha
# Out:
# ['n', 'g', 'r', 'a', 'b']

# %%
n = [1,2,5,100,0]

# %%
# 100, 5, 2, 1, 0

# %%
n.sort()

# %%
n
# Out:
# [0, 1, 2, 5, 100]

# %%
n.reverse()

# %%
n
# Out:
# [100, 5, 2, 1, 0]

# %%
n = [1,2,5,100,0]

n.sort()
n.reverse()
print(n)
# Out:
# [100, 5, 2, 1, 0]

# %%
n
# Out:
# [100, 5, 2, 1, 0]

# %%
length:- which is used to get len of our list
=======

# len

# %%
len(n)
# Out:
# 5

# %%
n
# Out:
# [100, 5, 2, 1, 0]

# %%
n[len(n)-1]
# Out:
# 0

# %%
# remove(item)

# pop(index_pos)

# %%
n
# Out:
# [100, 5, 2, 1, 0]

# %%
n.remove(2)

# %%
n
# Out:
# [100, 5, 1, 0]

# %%
# Slicing concept in list:-
# ==========================

langs = ['python','java','scala','js','c++','c']

# syntax :- list_name[intial_index:end_index:index_jump]

# %%
langs[0]
# Out:
# 'python'

# %%
langs[0:2+1]
# Out:
# ['python', 'java', 'scala']

# %%
lang_slice = langs[langs.index('python'):langs.index('scala')+1]

# %%
lang_slice
# Out:
# ['python', 'java', 'scala']

# %%
type(lang_slice)
# Out:
# list

# %%
langs
# Out:
# ['python', 'java', 'scala', 'js', 'c++', 'c']

# %%
langs[:2+1]
# Out:
# ['python', 'java', 'scala']

# %%
langs[:]
# Out:
# ['python', 'java', 'scala', 'js', 'c++', 'c']

# %%
langs[0:4:1]
# Out:
# ['python', 'java', 'scala', 'js']

# %%
langs[0:4:2]
# Out:
# ['python', 'scala']

# %%
langs[::2]
# Out:
# ['python', 'scala', 'c++']

# %%
langs
# Out:
# ['python', 'java', 'scala', 'js', 'c++', 'c']

# %%
'aa' in langs
# Out:
# False

# %%
"java" in langs
# Out:
# True

# %%
names = [.....]

names.sort()


============================================

names = [....]

names_sorted = sorted(names)
