# %%
KT Session ===> knowledge Transfer

slowly you will Work on tasks 

we should create one table ====> table_name, fields (names, datatype) ====> source 

Business owners (dept, salary) =====> BA ===> mapping doc (filed source, taget, datatype, join codiditon)  ====> DE (table to table)  ==> 1 point  ====> Unit testing (dev)===> QA env =====> Data quality check (QA) =====> prod 

file to table

# %%
dev  ===> done

QA  ====> 

prod ===>

# %%
model ===> agile methodology

Sprints ====> 

PI = project iteration (5 sprint)

sprint1 ===> 2 weeks
sprint2 
sprint3
sprint4
sprint5  ===> estimation 

1 point = 1 day ===> 100 points
