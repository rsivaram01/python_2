# %%
Python ==> Completed

SQL   ===> 2 sessions 

Big Data

# %%
Interview pattren:-
=================

1. python
2. SQL
3. Apache Spark  ---> theory
4. pyspark
5. Cloud --> Databricks 


================================================

project ---> next question

# %%
SQL:-
====

Why DE need SQL?
 Data Eng --------> Data? ( files, Databses, Api )

files --> csv, json, text, excel, xml, fixed width files.. etc
Databases ---> mysql, sqlserver, postgress sql, oracle sql.. etc
API ---> we will send get request to api, so api will give us data in json format

# %%
sqlserver ( emp ) ----> emp sal> 5000 ---> emp names csv format --> other team

# %%
SQL:-
====

creat table
insert, update, delete
alter commands

# %%
We will have data in mutiple tables:-
------------------------------------
emp, dept

dept_id

joins ---> left, inner join 


views:-
======

how to create a view

ship_locator table ---> loading  every 3 hrs  ===>  shipname, timestamp, lat, long, inserted_ts

select * from ship_locator

view:-
select * from ship_locator

# %%
CTE ---> common table expression

with active_emp_data as (
    select * from emp where status = 'active'
)

select * from active_emp_data

# %%
where class --->

to filter the data 

select * from emp where sal>300;

# %%
# group by , having

empid, empname, deptid, sal
                    1
                    2
                    3


select deptid,max(sal) from emp group by deptid

# %%
# window funcitons:-
===================

row_number()
rank()
dense_rank()
lead()
lag()

# %%
overwrite, append

# %%
overwrite:-
===========

yes ---> 3 rec

today ---> 2

tbl --> 2 records

# %%
tmrw:-
======

SCD ---> slowly changing dimenion
madallion arch -->

# %%
Basics in sqL --> create, update, delete, truncate
joins
filter condition where, qualify
window funcitons --> row_number, rank, dense_rank
group by , having
you should learn how to use CTE in writing query
View creation
