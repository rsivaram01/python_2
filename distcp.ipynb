# %%
2 clusters


1. Batch Cluster 
   This is used process historic data 

2. Near Real Time Cluster or NRT or Real Time cluster  ==> spark streaming
   This is used to process real time data 




2 ====> 1

2 ===> copyToLocal ===> copyFromLocal 1  ------> 10mb 
2 ===> copyToLocal ===> copyFromLocal 1  ------> 100gb 

========================================================================================================================================================

/data1/emp.json ---> 40mb
/data2/emp.json ----> 40mb

/data1/emp.json ---> 40gb
/data2/emp.json ----> 40gb

hdfs dfs -cp /data1/emp.json /data2/   ---> 2 sec for 40mb
hdfs dfs -cp /data1/emp.json /data2/   ---> time? for 40gb


hadoop distcp 

distcp ----> distributed copy 

hadoop distcp \
  -update \
  -overwrite \
  -delete \
  -skipcrccheck \
  -m 20 \
  /data1/emp.json \
  /data2/

Hadoop distcp is map side job only.......



40/20 ===> 2gb

20 map jobs ====> to copy the 40gb file 


map reduce job ====> /data2/ 


options:-
============


  -update  ===> 1000 ===> 200files 
  -overwrite \
  -delete \
  -skipcrccheck \
