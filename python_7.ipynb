# %%
cls = {'stu1':'Ashok',
        'stu2':'naveen',
        'stu3':'murali'}

# %%
type(cls)
# Out:
# dict

# %%
cls['stu1']
# Out:
# 'Ashok'

# %%
keys = cls.keys()

# %%
type(keys)
# Out:
# dict_keys

# %%
keys
# Out:
# dict_keys(['stu1', 'stu2', 'stu3'])

# %%
# type casting

# %%
keys_list = list(keys)

# %%
keys_list
# Out:
# ['stu1', 'stu2', 'stu3']

# %%
type(keys_list)
# Out:
# list

# %%
values = cls.values()

# %%
values
# Out:
# dict_values(['Ashok', 'naveen', 'murali'])

# %%
values_list = list(values)

# %%
values_list
# Out:
# ['Ashok', 'naveen', 'murali']

# %%
v_list = list(cls.values())

# %%
v_list
# Out:
# ['Ashok', 'naveen', 'murali']

# %%
# looping thru dict ==> for

# %%
# student Id : key , student_name : value

# %%
for i,j in cls.items():
    print(f"student Id : {i} , student_name : {j}")
# Out:
# student Id : stu1 , student_name : Ashok
# student Id : stu2 , student_name : naveen
# student Id : stu3 , student_name : murali

# %%
print(cls.items())
# Out:
# dict_items([('stu1', 'Ashok'), ('stu2', 'naveen'), ('stu3', 'murali')])

# %%
for i in cls.keys():
    print(i)
# Out:
# stu1
# stu2
# stu3

# %%
for j in cls.values():
    print(j)
# Out:
# Ashok
# naveen
# murali

# %%
# set:-
=======

# what is Set?

Set is also a collection in python, which can be used to store multiple items in a single variable.

Set is actually diffrent from other collections, 

A set is an unorders and unindex collection.

# how do we declare a set?

Set can be declared with {}

Sets are used to carry out math set operations like union, intersections... etc


# Most imp:-
----------

    Set won't accepts duplciates

    Set is an mutable datatype

# %%
dict1 = {'a':'ddf', 'fddf':'fddf'}

# %%
set1 = {1,2,3,4}

# %%
print(type(set1), type(dict1))
# Out:
# <class 'set'> <class 'dict'>

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
# how do we find len of a set

# %%
len(set1)
# Out:
# 4

# %%
set2 = {1,2,3,2,23,23,1,23}

# %%
set2
# Out:
# {1, 2, 3, 23}

# %%
l1 = [1,23,3,23,54,23,76,1]

# %%
l1
# Out:
# [1, 23, 3, 23, 54, 23, 76, 1]

# %%
# I want to eliminate dupli form my list

# %%
# type casting ===> list ===> set ====> list

# %%
l1
# Out:
# [1, 23, 3, 23, 54, 23, 76, 1]

# %%
s_l1 = set(l1)

# %%
s_l1
# Out:
# {1, 3, 23, 54, 76}

# %%
s_l1_list = list(s_l1)

# %%
s_l1_list
# Out:
# [1, 3, 76, 54, 23]

# %%
l1
# Out:
# [1, 23, 3, 23, 54, 23, 76, 1]

# %%
new_list = list(set(l1))

# %%
new_list
# Out:
# [1, 3, 76, 54, 23]

# %%
# lopping thru set:-
==================

# %%
for i in set2:
    print(i)
# Out:
# 1
# 2
# 3
# 23

# %%
# add a new item

add()

# %%
set2
# Out:
# {1, 2, 3, 23}

# %%
set2.add(50)

# %%
set2
# Out:
# {1, 2, 3, 23, 50}

# %%
# I want to remove an item from set

# Remove()

# %%
set2
# Out:
# {1, 2, 3, 23, 50}

# %%
set2.remove(23)

# %%
set2
# Out:
# {1, 2, 3, 50}

# %%
# another method to remove

discard()

# %%
set2.discard(50)

# %%
set2
# Out:
# {1, 2, 3}

# %%
set2
# Out:
# {1, 2, 3}

# %%
set2.remove(23)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 set2.remove(23)
#
# KeyError: 23

# %%
set2.discard(23)

# %%
set2.pop()
# Out:
# 1

# %%
set2.pop()
# Out:
# 2

# %%
set2
# Out:
# {3}

# %%
set2.pop()
# Out:
# 3

# %%
set2
# Out:
# set()
