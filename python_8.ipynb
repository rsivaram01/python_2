# %%
# functions:-
===========

what is function?
functions is block of code or statament used to execute specific task

How to define a fucntion?
with a key word called def

For code reusability we need to use functions

# how to comment inside a function?

""" this is comment inside a function """

# %%
# req:- make multiplication funuction

# %%
for i in range(10):
    print(f"2*{i}={2*i}")
# Out:
# 2*0=0
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18

# %%
def multi(x):
    for i in range(10):
        print(f"{x}*{i}={x*i}")

# %%
multi(10)
# Out:
# 10*0=0
# 10*1=10
# 10*2=20
# 10*3=30
# 10*4=40
# 10*5=50
# 10*6=60
# 10*7=70
# 10*8=80
# 10*9=90

# %%
multi(12345678)
# Out:
# 12345678*0=0
# 12345678*1=12345678
# 12345678*2=24691356
# 12345678*3=37037034
# 12345678*4=49382712
# 12345678*5=61728390
# 12345678*6=74074068
# 12345678*7=86419746
# 12345678*8=98765424
# 12345678*9=111111102

# %%
def greet_user(name):
    """ this fucniton is used to greet a user"""
    print(f"welcome Back {name}!!")

# %%
greet_user('naveen')
# Out:
# welcome Back naveen!!

# %%
for i in range(10):
    print(f"3*{i}={3*i}")
# Out:
# 3*0=0
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27

# %%
multi(3)
# Out:
# 3*0=0
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27

# %%
# types of arguments:-
======================

1. positional argugemts
2. keyword arguments

# %%
# positional arguments:-
-----------------------

# %%
# python is case sensitive languge
# python is an indentad language

indentation is nothing but style of writing

# %%
def desc_pets(animal_type, animal_name):
    print(f"my animal type is {animal_type}\n")
    print(f"my {animal_type} name is {animal_name}")

# %%
desc_pets("dog","bruno")
# Out:
# my animal type is dog
#
# my dog name is bruno

# %%
desc_pets("bruno","dog")
# Out:
# my animal type is bruno
#
# my bruno name is dog

# %%
# keyword args:-
--------------

# %%
def desc_pets(animal_type, animal_name):
    print(f"my animal type is {animal_type}\n")
    print(f"my {animal_type} name is {animal_name}")

# %%
desc_pets("cheetha", "bhagira")
# Out:
# my animal type is cheetha
#
# my cheetha name is bhagira

# %%
desc_pets(animal_type = 'cheetha', animal_name = 'bhagira')
# Out:
# my animal type is cheetha
#
# my cheetha name is bhagira

# %%
desc_pets(animal_name = 'simba', animal_type = 'lion')
# Out:
# my animal type is lion
#
# my lion name is simba

# %%
def desc_pets(animal_type, animal_name):
    print(f"my animal type is {animal_type}\n")
    print(f"my {animal_type} name is {animal_name}")

# %%
def stu(num_of_stu):
    print(f"I'm having {num_of_stu} students")

# %%
stu(3)
# Out:
# I'm having 3 students

# %%
stu(num_of_stu = 3)
# Out:
# I'm having 3 students

# %%
stu()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 stu()
#
# TypeError: stu() missing 1 required positional argument: 'num_of_stu'

# %%
def stu_1(num_of_stu = 100):
    print(f"I'm having {num_of_stu} students")

# %%
stu_1()
# Out:
# I'm having 100 students

# %%
stu_1(0)
# Out:
# I'm having 0 students

# %%
# req:- 
I'm having 3 students
naveen
ashok
murali

# %%
def stu_2(num_of_stu, *students):
    print(f"I'm having {num_of_stu} students")
    for i in students:
        print(i)

# %%
stu_2(3, 'naveen','ashok','murali','saas','sdfdfere')
# Out:
# I'm having 3 students
# naveen
# ashok
# murali
# saas
# sdfdfere

# %%
def addition(a,b):
    print(a+b)

# %%
addition(10,20)
# Out:
# 30

# %%
def addition_1(a,b):
    return a+b

# %%
res_1 = addition_1(3,3)

# %%
res_1
# Out:
# 6

# %%
addition_1(3,3)
# Out:
# 6

# %%
addition(3,3)
# Out:
# 6

# %%
def addition_1(a,b):
    return a+b

def power_fun(num,power_value):
    print(num**power_value)

# %%
n = addition_1(3,3)
power_fun(n,3)
# Out:
# 216

# %%
# Introdcutions to python classes:-
==================================

Class - Objets  ====> Oops

Class :- class is blue print of an object 
With one class we can create N number of objects 

Method:-
=======

what is a method?
if you define a fucniton inside a class is called method

# %%
class exampleClass:
    eyes = 'blue'
    age = 32

    def mymethod(self):
        print(f"my eyes are {self.eyes}")
        print(f"my age is {self.age}")

# %%
# self :- temp place holder for storing current object

# %%
# how to create an object

obj1 = exampleClass()

# %%
obj1.eyes
# Out:
# 'blue'

# %%
obj1.age
# Out:
# 32

# %%
obj1.mymethod()
# Out:
# my eyes are blue
# my age is 32

# %%
obj2 = exampleClass()

# %%
obj2.mymethod()
# Out:
# my eyes are blue
# my age is 32

# %%
class stu:
    def stu_name(self,name):
        self.name = name
        print(f"my student name is {self.name}")

# %%
id(stu1)
# Out:
# 2175581267888

# %%
stu1 = stu()

# %%
stu1.stu_name("naveen")
# Out:
# my student name is naveen

# %%
stu2 = stu()
stu2.stu_name("ashok")
# Out:
# my student name is ashok

# %%
stu1.name
# Out:
# 'naveen'

# %%
stu2.name
# Out:
# 'ashok'
