# %%
# python  

in data eng:-
===========

we need to process data by using apche spark ===> pyspark, pandas ===> we need to learn python  


interviews:-
===========

1. SQL
2. Apche Spark ( theory part question )
3. pyspark ( coding question )
4. python ( theory or coding )

apart from if they are looking for any other skill set they might ask the question

# %%
# python

# %%
# variable

variable:- var is a just a like a container to store some data or value

# %%
a = 10

# %%
a
# Out:
# 10

# %%
b = 15

# %%
b
# Out:
# 15

# %%
# rules to declare variables in python 

1. No spaces were allowed in the variable names
2. No special char as allowed in the var names
3. var name should not start with a number

# %%
full name = 'naveen'
# Out:
#   Cell In[5], line 1
#     full name = 'naveen'
#          ^
# SyntaxError: invalid syntax

# %%
full_name = 'naveen'

# %%
full_name
# Out:
# 'naveen'

# %%
print(full_name)
# Out:
# naveen

# %%
# 2. No special char as allowed in the var names except underscore

# %name = 'aa'
# Out:
# UsageError: Line magic function `%name` not found.

# %%
$name = 'bb'
# Out:
#   Cell In[10], line 1
#     $name = 'bb'
#     ^
# SyntaxError: invalid syntax

# %%
# 3. var name should not start with a number

1name = 'ad'
# Out:
#   Cell In[11], line 3
#     1name = 'ad'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'adg'

# %%
name1
# Out:
# 'adg'

# %%
print(name1)
# Out:
# adg

# %%
# this code will filter some data 
sahsba
sajsabsaashbas
ffdfdjdf
fjfdj

# %%
# comments in python

types of comments in python

1. single line comment
2. Multi line comment

# %%
# this is single line comment

# %%
""" 
this is multi line comment
dbdshdsbdsbh

dshdsbdsh

dashdsbhdsb

asdjd

"""

# %%
# this is used to print full_name

print(full_name)
# Out:
# naveen

# %%
# this is used to print full_name 

print(full_name)
# Out:
# naveen

# %%
# Introduction to DataTypes in Python:-
======================================

1. String    ====> str
2. list      ====> list
3. Tuple     ====> tuple
4. Dictionary  ==> dict
5. Sets     =====> set

# %%
# String    ====> str

What is string?
ans. String is a series or collection of charecters  

How to delcare string in python?
There are 3 ways to declare string in python

1. 'py'
2. "py"
3. '''py'''

# properties of strings?
========================
String is a immutable datatype

Immutable :- No change or ater/ modification is possible after it get declared 
mutable :- alter or modfication is possible after it get declared as well

# %%
name = 'python'
name1 = "python"
name2 = '''python'''

# %%
print(name, name1, name2)
# Out:
# python python python

# %%
sent = 'this is my notebook'

# %%
print(sent)
# Out:
# this is my notebook

# %%
# req :- this is ashok's notebook

# %%
sent1 = "this is ashok's notebook"

# %%
print(sent1)
# Out:
# this is ashok's notebook

# %%
# req:- this very "imp"

# %%
print('''this is very "imp"''')
# Out:
# this is very "imp"
