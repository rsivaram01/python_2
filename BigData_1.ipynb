# %%
tbl - emp_details  - 120 columns ==> phno, email = 118

select * from emp_details;


select *except(phno,email) from emp_details;

**read about Qualify

# %%
Fundamentals:-
=============

PYTHON
SQL


Intermidtae Level:-
==================
Big Data Tech ===> Hadoop

# %%
Big Data:-
=======
 we charecsticts:-

3 v's

volume   -----> it represents the size of the data
variety ----->  types of data ==> stractured data, semi stractured data and un stractured data ===> RDMS, (json, csv, xml) , (app logs, video, audio)
velocity --> the rate at which data being generated

# %%
Hadoop:-
=======

Cluster manager
Distributed computation engine
Distributed file system

# %%
File system:- HDFS
===========

File formats:-
===========

CSV, text, json, xml ==> 40 GB  ---> 40 GB  ===> not ideal 

Columnar file formats:-
======================

# %%
Big Data:-
=========
